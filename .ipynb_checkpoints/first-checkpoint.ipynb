# %% [markdown]
# ## SYDE 750 Assignment 1: Representation in Populations of Neurons
#
# ### By Tushar Chopra
#
# * Due Date: January 28th at midnight
# * Total marks: 20 (20% of final grade)
# * Late penalty: 1 mark per day
# * It is recommended that you use Python.
# * Do not use or refer to any code from Nengo

# %% [markdown]
# ## 1) Representation of Scalars

# %% [markdown]
# ### 1.1) Basic encoding and decoding
# Write a program that implements a neural representation of a scalar value  𝑥 . For the neuron model, use a rectified linear neuron model ( 𝑎=𝑚𝑎𝑥(𝐽,0) ). Choose the maximum firing rates randomly (uniformly distributed between 100Hz and 200Hz at x=1), and choose the x-intercepts randomly (uniformly distributed between -0.95 and 0.95). Use those values to compute the corresponding  𝛼  and  𝐽𝑏𝑖𝑎𝑠  parameters for each neuron. The encoders  𝑒  are randomly chosen and are either +1 or -1 for each neuron. Go through the following steps:

# %%
# %pylab inline
import numpy as np

class RLNeuron:
    
    def __init__(self):
        
        self.max_firing_rate = np.random.uniform(low = 100, high = 200)
        self.x_intercept = np.random.uniform(low = -0.95,high = 0.95)
        self.encoder = np.random.choice([1,-1])
        
        self.alpha = self.max_firing_rate/(1-self.x_intercept)
        self.j_bias = -self.alpha * self.x_intercept
        
        
def computeNeurons(n,X):
    neuron_values_array = np.zeros([n,len(X)])
    for i in range(0,n):
        neu = RLNeuron()
        for j,x in enumerate(X): 
            a = neu.encoder * neu.alpha * x + neu.j_bias
            neuron_values_array[i][j] = max(a, 0)
    return neuron_values_array
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# a). [1 mark] Plot the neuron responses  𝑎𝑖  for 16 randomly generated neurons. (See Figure 2.4 in the book for an example, but with a different neuron model and a different range of maximum firing rates).
# Since you can't compute this for every possible  𝑥  value between -1 and 1, sample the x-axis with  𝑑𝑥=0.05 . Use this sampling throughout this question)

# %%
number_of_samples = (1-(-1))/0.05
number_of_neurons = 16
X = np.linspace(-1,1,number_of_samples)
A = computeNeurons(number_of_neurons, X)

for i in range(0,number_of_neurons):
    plot(X, A[i])
xlabel('$x$ (stimuli)')
ylabel('$a$ (firing rate)')
title('Rectified Linear Neurons');
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# b). [1 mark] Compute the optimal decoders  𝑑𝑖  for those 16 neurons (as shown in class). Report their values.
# The easiest way to compute  𝑑  is to use the matrix notation mentioned in the course notes.  𝐴  is the matrix of neuron activities (the same thing used to generate the plot in 1.1a).

# %%
def decodeNeurons(A):
    upsilon = np.matmul(A,X) / number_of_samples
    gamma = np.matmul(A, np.transpose(A))/ number_of_samples
    gamma_inv = np.linalg.inv(gamma)
    d = np.dot(gamma_inv, upsilon)
    return d
d=decodeNeurons(A)
print("Decoders:",d)
# Out:
# Decoders: [-4.48441652e-07  3.16577375e-07  1.16006075e-04 -1.68608517e-03
#  -7.33678007e-10  5.57140933e-04 -8.46199453e-04 -1.56511269e-05
#  -1.69746404e-03  6.71029412e-03 -7.21642112e-03  1.09842111e-07
#   2.03040704e-04  4.73609479e-06 -5.01992986e-05  1.05862030e-05]

# %% [markdown]
# c). [1 mark] Compute and plot  𝑥̂ =∑𝑖𝑑𝑖𝑎𝑖 . Overlay on the plot the line  𝑦=𝑥 . (See Figure 2.7 for an example). Make a separate plot of  𝑥−𝑥̂   to see what the error looks like. Report the Root Mean Squared Error value.

# %%
X_hat = np.matmul(np.transpose(A),d)
def getRMS(X, X_hat):
    RMS = 0
    Diff = X - X_hat
    for x in range(0,len(X)):
        RMS += np.power(Diff[x],2)
    RMS = np.sqrt(RMS/len(X))
    return RMS, Diff

RMS1, Diff = getRMS(X, X_hat)
print("RMS error = ", str(RMS1))
# Out:
# RMS error =  0.00026417579589901684

# %%
plot(X, X)
plot(X, X_hat)
xlabel('$x$')
ylabel('$x$')
title('Expected vs. Decoded stimulus');

# %%
plot(X, Diff)
xlabel('$x (stimulus)$')
ylabel('$epsilon$')
title('Error in Decoded Stimulus');

# %% [markdown]
# d). [1 mark] Now try decoding under noise. Add random normally distributed noise to  𝑎  and decode again. The noise is a random variable with mean 0 and standard deviation of 0.2 times the maximum firing rate of all the neurons. Resample this variable for every different  𝑥  value for every different neuron. Create all the same plots as in part c). Report the Root Mean Squared Error value.

# %%
def generateNoise(A,scale):
     return A + np.random.normal(loc = 0, scale = scale * np.max(A), size = A.shape)

Anoise = generateNoise(A, 0.2)
for i in range(0,number_of_neurons):
    plot(X, Anoise[i])

# %%
X_hat_noise = np.matmul(Anoise.transpose(),d)
plot(X, X)
plot(X, X_hat_noise)
xlabel('$x$')
ylabel('$x$')
title('Expected vs. Decoded stimulus in Noisy neurons');

# %%
Diff = X - X_hat_noise
plot(X, Diff)
xlabel('$x (stimulus)$')
ylabel('$epsilon$')
title('Error in Noicy Decoded Stimulus');

# %% [markdown]
# e). [1 mark] Recompute the decoders  𝑑𝑖  taking noise into account (as shown in class). Show how these decoders behave when decoding both with and without noise added to  𝑎  by making the same plots as in c) and d). Report the RMSE for both cases.
# As in the previous question,  𝜎  is 0.2 times the maximum firing rate of all the neurons.

# %%
def decodeWithNoise(A):
    upsilon = np.matmul(A,X) / number_of_samples
    gamma = np.matmul(A, np.transpose(A))/ number_of_samples
    var = np.power(0.2 * np.max(A),2) * np.identity(A.shape[0])
    gamma+=var
    gamma_inv = np.linalg.inv(gamma)
    d_noise = np.dot(gamma_inv, upsilon)
    return d_noise
d_noise = decodeWithNoise(Anoise)
print("Decoded with noise:",d_noise)
# Out:
# Decoded with noise: [-5.13838407e-04 -1.23428686e-03 -3.76553296e-04  1.25685828e-03
#  -3.72506817e-04  4.65804669e-04 -1.87631370e-04 -1.33314435e-03
#  -1.80291100e-03  1.25673246e-03 -1.52180115e-03 -8.76357461e-05
#   5.41491450e-04  1.03215819e-03  1.32335502e-04  1.30132584e-03]

# %%
X_hat_noise = np.matmul(np.transpose(Anoise),d_noise)

def getRMS(X, X_hat_noise):
    RMS = 0
    Diff = X - X_hat_noise
    for x in range(0,len(X)):
        RMS += np.power(Diff[x],2)
    RMS = np.sqrt(RMS/len(X))
    return RMS, Diff

RMS1, Diff_noise = getRMS(X, X_hat_noise)
print("RMS error = ", str(RMS1))
# Out:
# RMS error =  0.19351795125203985

# %%
plot(X, X)
plot(X, X_hat_noise)
xlabel('$x$')
ylabel('$x$')
title('Expected vs. Decoded stimulus - Accounting for noise');

# %%
plot(X, Diff_noise)
xlabel('$x$ (stimulus)')
ylabel('$\epsilon$')
title('Error in Decoded stimulus - Accounting for noise');

# %% [markdown]
# f). [1 mark] Show a 2x2 table of the four RMSE values reported in parts c), d), and e). This should show the effects of adding noise and whether or not the decoders  𝑑  are computed taking noise into account. Write a few sentences commenting on what the table shows.

# %%
print("Clean Neurons, Original Decoder \nRMS = " , str(RMS1) , "\n")
print("Noisy Neurons, Original Decoder \nRMS = " , str(RMS1) , "\n")
print("Noisy Neurons, Noisy Decoder \nRMS = " , str(RMS1) , "\n")
print("Clean Neurons, Noisy Decoder \nRMS = " , str(RMS1) , "\n")
# Out:
# Clean Neurons, Original Decoder
# RMS =  0.19351795125203985
#
# Noisy Neurons, Original Decoder
# RMS =  0.19351795125203985
#
# Noisy Neurons, Noisy Decoder
# RMS =  0.19351795125203985
#
# Clean Neurons, Noisy Decoder
# RMS =  0.19351795125203985

# %% [markdown]
# Write text here-----------------------------

# %% [markdown]
# ## 1.2 Started

# %% [markdown]
# <ol style="list-style:lower-alpha outside none;" start="1">
# <li>[2 marks] Plot the error due to distortion $E_{dist}$ and the error due to noise $E_{noise}$ as a function of $N$, the number of neurons. Use the equation with those two parts as your method (2.9 in the book). Generate two different loglog plots (one for each type of error) with $N$ values of [4, 8, 16, 32, 64, 128, 256, 512] (and more, if you would like).  For each $N$ value, do at least 5 runs and average the results.  For each run, different $\alpha$, $J^{bias}$, and $e$ values should be generated for each neuron.  Compute $d$ under noise, with $\sigma$ equal to 0.1 times the maximum firing rate.  Show visually that the errors are proportional to $1/N$ or $1/N^2$ (see figure 2.6 in the book).
# </li>
# </ol>

# %%
def getErrorSources(A):
    d = decodeWithNoise(A)
    X_hat = np.matmul(A.transpose(),d)
    Edist = 0.5 * np.sum((X - X_hat)**2)
    var = 0.2 * np.max(A)**2
    Enoise = var * np.sum(d**2)
    return Edist, Enoise
    
N = [4, 8, 16, 32, 64, 128, 256, 512]
E_dist = np.zeros(len(N))
E_noise = np.zeros(len(N))

for i,n in enumerate(N):
    print ("Running n = " , str(n))
    Edist_i = [0] * 5
    Enoise_i = [0] * 5
    for j in range(0,5):
        A_ = computeNeurons(n,X)
        Anoise = generateNoise(A_,0.1)
        Ed, En = getErrorSources(Anoise)
        Edist_i += Ed
        Enoise_i += En
        #print(Edist_i)
        #print(Enoise_i)
    E_dist[i] = np.mean(Edist_i)
    E_noise[i] = np.mean(Enoise_i)
    #print(E_dist[i])
    #print(E_noise[i])
    #print("------------------------------")
print(E_dist)
print(E_noise)
    
print ("OK")
# Out:
# Running n =  4
# Running n =  8
# Running n =  16
# Running n =  32
# Running n =  64
# Running n =  128
# Running n =  256
# Running n =  512
# [7.35214143e+00 2.55461325e+00 1.02663731e+00 3.00093572e-01
#  9.27382269e-02 3.39273922e-02 8.99542488e-03 1.91561935e-03]
# [1.04708092 0.91039326 0.59636487 0.33300744 0.16134794 0.09274503
#  0.0496018  0.02650893]
# OK

# %%
N_inv = [0] * len(N)
N_inv2 = [0] * len(N)
for i,m in enumerate(N):
    N_inv[i] = (m**(-1))
    N_inv2[i] = (m**(-2))

loglog(N, E_dist, label = "Error")
loglog(N,N_inv, 'r--', label="1/$N$")
loglog(N,N_inv2, 'g--', label="1/$N^2$")
plt.legend()
xlabel('$N$')
ylabel('$E_{dist}$')
title('Error due to Distortion ($\sigma = 10\%$)');

# %%
loglog(N, E_noise,'b', label="Error")
loglog(N,N_inv, 'r--', label="1/$N$")
loglog(N,N_inv2, 'g--', label="1/$N^2$")
plt.legend()
xlabel('$N$')
ylabel('$E_{noise}$')
title('Error due to Noise ($\sigma = 10\%$)');

# %% [markdown]
# b). [1 mark] Repeat part a) with  𝜎  equal to 0.01 times the maximum firing rate.

# %%
E_dist2 = np.zeros(len(N))
E_noise2 = np.zeros(len(N))

for i,n in enumerate(N):
    print ("Running n = " , str(n))
    Edist_i = [0] * 5
    Enoise_i = [0] * 5
    for j in range(0,5):
        A_ = computeNeurons(n,X)
        Anoise = generateNoise(A_,0.01)
        Ed, En = getErrorSources(Anoise)
        Edist_i += Ed
        Enoise_i += En
    E_dist2[i] = np.mean(Edist_i)
    E_noise2[i] = np.mean(Enoise_i)
print ("OK")
# Out:
# Running n =  4
# Running n =  8
# Running n =  16
# Running n =  32
# Running n =  64
# Running n =  128
# Running n =  256
# Running n =  512
# OK

# %%
loglog(N, E_dist2, label = "Error")
loglog(N,N_inv, 'r--', label="1/$N$")
loglog(N,N_inv2, 'g--', label="1/$N^2$")
plt.legend()
xlabel('$N$')
ylabel('$E_{dist}$')
title('Error due to Distortion ($\sigma = 1\%$)');

# %% [markdown]
# c). [1 mark] What does the difference between the graphs in a) and b) tell us about the sources of error in neural populations?

# %% [markdown]
# Write text answer

# %% [markdown]
# ### 1.3) Leaky Integrate-and-Fire neurons
#
# Change the code to use the LIF neuron model:
#
# $$
# a_i = \begin{cases}
#     {1 \over {\tau_{ref}-\tau_{RC}ln(1-{1 \over J})}} &\mbox{if } J>1 \\
#     0 &\mbox{otherwise}
#     \end{cases}
# $$

# %%
class LIFNeuron:
    
    def __init__(self, tau_ref, tau_rc):
        
        self.max_firing_rate = np.random.uniform(low = 100, high = 200)
        self.x_intercept = np.random.uniform(low = -0.95,high = 0.95)
        self.encoder = np.random.choice([1,-1])
        
        self.alpha = 1/(1+self.x_intercept) * 1/(1-np.exp((self.max_firing_rate*tau_ref - 1)/(self.max_firing_rate*tau_rc)))
        self.j_bias = self.alpha * self.x_intercept
        
        
def computeLIFNeurons(n,X, tau_ref, tau_rc):
    neuron_values_array = np.zeros([n,len(X)])
    for i in range(0,n):
        neu_lif = LIFNeuron(tau_ref, tau_rc)
        for k,x in enumerate(X): 
            j = neu_lif.encoder * neu_lif.alpha * x + neu_lif.j_bias
            a = (tau_ref - (tau_rc*np.log(1-j**(-1))))**(-1) if (j > 1) else 0
            neuron_values_array[i][k] = max(a, 0)
    return neuron_values_array

# %% [markdown]
# a). [1 mark] Generate the same plot as 1.1a). Use  𝜏𝑟𝑒𝑓=0.002 s and  𝜏𝑅𝐶=0.02 s.
#
# Note that you will need to compute new  𝛼  and  𝐽𝑏𝑖𝑎𝑠  values that will achieve the desired tuning curves (uniform distribution of x-intercepts between -1 and 1, and maximum firing rates between 100Hz and 200Hz). Since you know two points on the tuning curve (the x-intercept and the point where it hits maximum firing), this gives you 2 equations and 2 unknowns, so you can find  𝛼  and  𝐽𝑏𝑖𝑎𝑠  by substituting and rearranging.

# %%
number_of_samples = (1-(-1))/0.05
number_of_neurons = 16
X = np.linspace(-1,1,number_of_samples)
A_lif = computeLIFNeurons(number_of_neurons, X,tau_ref = 0.002, tau_rc = 0.02)

for i in range(0,number_of_neurons):
    plot(X, A_lif[i])
xlabel('$x$ (stimuli)')
ylabel('$a$ (firing rate)')
title('LIF Neurons');
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# b). [2 marks] Generate the same plots as 1.1e), and report the RMSE for both.

# %%
d_lif = decodeNeurons(A_lif)
print("Decoders: \n\n d = ", str(d_lif))
# Out:
# Decoders:
#
#  d =  [-6.41341784e-04  2.64940444e-03 -7.49962450e-04 -1.91237799e-03
#  -1.97821423e-03  5.30002794e-04  6.55452556e-04 -2.66237152e-04
#  -9.06548303e-05 -1.03572115e-02  4.21157377e-03  2.11762490e-03
#  -1.86224837e-03  5.67068378e-03  7.84187927e-03 -7.55474427e-04]

# %%
X_hat_lif = np.matmul(A_lif.transpose(), d_lif)

RMS_lif, diff = getRMS(X, X_hat_lif)
print("RMS error = ", str(RMS_lif))
plot(X, X)
plot(X, X_hat_lif)
xlabel('x')
ylabel('x')
title('Expected vs. Decoded stimulus');
# Out:
# RMS error =  0.011551852202423118

# %%
A_noise_lif = generateNoise(A_lif,0.2)
for i in range(0,A_lif.shape[0] - 1): #for each neuron
    plot(X, A_noise_lif[i])
xlabel('$x$ (stimulus)')
ylabel('$a$ (firing rate)')
title('Noisy LIF Neurons');

# %%
X_hat_noise_lif = np.matmul(A_noise_lif.transpose(),d_lif)

RMS_noise_lif, diff = getRMS(X, X_hat_noise_lif)
print ("RMS error = ", str(RMS_noise_lif))
plot(X, X)
plot(X, X_hat_noise_lif)
xlabel('$x$')
ylabel('$x$')
title('Expected vs. Decoded stimulus');
# Out:
# RMS error =  0.6518944621764104

# %%
d_noise_lif = decodeWithNoise(A_noise_lif)
X_hat_noise_lif2 = np.matmul(A_noise_lif.transpose(),d_noise_lif)

RMS_noise_lif2, Diff_noise = getRMS(X, X_hat_noise_lif2)
print ("RMS error = ", str(float(RMS_noise_lif2)))
plot(X, X)
plot(X, X_hat_noise_lif2)
xlabel('$x$')
ylabel('$x$')
title('Expected vs. Decoded stimulus - Accounting for noise');
# Out:
# RMS error =  0.09293379959078492

# %%
X_hat_clean_lif = np.matmul(A_lif.transpose(),d_noise_lif)

RMS_clean_lif, Diff_noise = getRMS(X, X_hat_clean_lif)
print ("RMS error = ", str(float(RMS_clean_lif)))

plot(X, X)
plot(X, X_hat_clean_lif)
xlabel('$x$')
ylabel('$x$')
title('Expected vs. Decoded - Clean Signal using Noisy Decoder');
# Out:
# RMS error =  0.06848833012957835
